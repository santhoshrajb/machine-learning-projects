# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("cars.csv")

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.dropna()
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df["normalized-losses"].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
df["normalized-losses"].replace("?",np.nan,inplace=True)

# %%
print(df["normalized-losses"].value_counts())
# Out:
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: normalized-losses, dtype: int64

# %%
df["horsepower"].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 160     6
# 114     6
# 84      5
# 97      5
# 102     5
# 145     5
# 82      5
# 76      5
# 111     4
# 92      4
# 123     4
# 86      4
# 90      3
# 73      3
# 85      3
# 207     3
# 182     3
# 121     3
# 152     3
# 112     2
# 56      2
# 161     2
# 156     2
# 94      2
# 52      2
# ?       2
# 162     2
# 155     2
# 184     2
# 100     2
# 176     2
# 55      1
# 262     1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 135     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: horsepower, dtype: int64

# %%
df["horsepower"].replace("?",np.nan,inplace=True)

# %%
print(df["horsepower"].value_counts())
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 160     6
# 101     6
# 62      6
# 88      6
# 145     5
# 76      5
# 97      5
# 82      5
# 84      5
# 102     5
# 92      4
# 111     4
# 123     4
# 86      4
# 207     3
# 182     3
# 90      3
# 121     3
# 152     3
# 85      3
# 73      3
# 161     2
# 94      2
# 56      2
# 112     2
# 184     2
# 155     2
# 156     2
# 52      2
# 100     2
# 162     2
# 176     2
# 140     1
# 115     1
# 134     1
# 78      1
# 48      1
# 288     1
# 143     1
# 142     1
# 200     1
# 58      1
# 55      1
# 60      1
# 175     1
# 154     1
# 72      1
# 120     1
# 64      1
# 135     1
# 262     1
# 106     1
# Name: horsepower, dtype: int64

# %%
df.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df["normalized-losses"]=df["normalized-losses"].astype("float64")

# %%
df["normalized-losses"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 205, dtype: float64

# %%
df["horsepower"]=df["horsepower"].astype("float64")

# %%
df["horsepower"]
# Out:
# 0      111.0
# 1      111.0
# 2      154.0
# 3      102.0
# 4      115.0
#        ...
# 200    114.0
# 201    160.0
# 202    134.0
# 203    106.0
# 204    114.0
# Name: horsepower, Length: 205, dtype: float64

# %%
nmean=df["normalized-losses"].mean()
nmean
# Out:
# 122.0

# %%
df["normalized-losses"]=df["normalized-losses"].fillna(nmean)

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.dropna(how="any",subset=["horsepower"],inplace=True)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...

# %%
feature=df.iloc[:,:-1]

# %%
target=df['price']

# %%
plt.figure(figsize=(5,5))
sb.boxplot(data=feature,x=target)
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(5,5))
plt.grid()
sb.boxplot(data=feature,x=target,y="make")
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
df[(df['make']=="dodge") & (df['price']>9000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3              145.0  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 29           front   66.3    50.2         ohc          156       145.0
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
df.loc[29,"price"]=9000

# %%
df[(df['make']=="honda") & (df['price']>10000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 40          0               85.0  honda       gas      sedan          fwd
# 41          0               85.0  honda       gas      sedan          fwd
# 42          1              107.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 40           front   62.5    54.1         ohc          110        86.0
# 41           front   65.2    54.1         ohc          110       101.0
# 42           front   66.0    51.0         ohc          110       100.0
#
#     city-mpg  highway-mpg  price
# 40        27           33  10295
# 41        24           28  12945
# 42        25           31  10345

# %%
df.loc[40:43,"price"]=9000

# %%
df[(df['make']=="isuzu") & (df['price']>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0              122.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90        70.0
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df.loc[45,"price"]=9000

# %%
df[(df['make']=="mitsubishi") & (df['price']>11000)]
# Out:
#     symboling  normalized-losses        make fuel-type body-style  \
# 82          3              122.0  mitsubishi       gas  hatchback
# 83          3              122.0  mitsubishi       gas  hatchback
# 84          3              122.0  mitsubishi       gas  hatchback
#
#    drive-wheels engine-location  width  height engine-type  engine-size  \
# 82          fwd           front   66.3    50.2         ohc          156
# 83          fwd           front   66.3    50.2         ohc          156
# 84          fwd           front   66.3    50.2         ohc          156
#
#     horsepower  city-mpg  highway-mpg  price
# 82       145.0        19           24  12629
# 83       145.0        19           24  14869
# 84       145.0        19           24  14489

# %%
df.loc[82:85,"price"]=8000

# %%
df[(df['make']=="plymouth") & (df['price']>10000)]
# Out:
#      symboling  normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3              122.0  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 124           front   66.3    50.2         ohc          156       145.0
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
df.loc[124,"price"]=7000

# %%
df[(df['make']=="toyota") & (df['price']>10000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 170          2              134.0  toyota       gas      hardtop          rwd
# 171          2              134.0  toyota       gas    hatchback          rwd
# 172          2              134.0  toyota       gas  convertible          rwd
# 174         -1               65.0  toyota    diesel        sedan          fwd
# 176         -1               65.0  toyota       gas        sedan          fwd
# 177         -1               65.0  toyota       gas    hatchback          fwd
# 178          3              197.0  toyota       gas    hatchback          rwd
# 179          3              197.0  toyota       gas    hatchback          rwd
# 180         -1               90.0  toyota       gas        sedan          rwd
# 181         -1              122.0  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# ...

# %%
df.loc[[170,171,172,174,176,177,178,179,180,181],"price"]=10000

# %%
colname=feature.select_dtypes(['int64','float64']).columns

# %% [markdown]
# colname

# %%
colname
# Out:
# Index(['symboling', 'normalized-losses', 'width', 'height', 'engine-size',
#        'horsepower', 'city-mpg', 'highway-mpg'],
#       dtype='object')

# %%
from scipy.stats import skew

# %%
skew(feature['symboling'])
sb.distplot(feature['symboling'])
# Out:
# <Axes: xlabel='symboling', ylabel='Density'>

# %%
for i in feature[colname]:
    print(i)
    print(skew(feature[i]))
    plt.figure()
    sb.distplot(feature[i])
    plt.show()
# Out:
# symboling
# 0.2119206488243259
# normalized-losses
# 0.8443855299694787
# width
# 0.9027470456759982
# height
# 0.06304602917236043
# engine-size
# 1.9279361610048402
# horsepower
# 1.3807297805235197
# city-mpg
# 0.6471122044457601
# highway-mpg
# 0.5344917338075725

# %%
df.corr()
# Out:
#                    symboling  normalized-losses     width    height  \
# symboling           1.000000           0.466709 -0.234364 -0.537520
# normalized-losses   0.466709           1.000000  0.084232 -0.372637
# width              -0.234364           0.084232  1.000000  0.282078
# height             -0.537520          -0.372637  0.282078  1.000000
# engine-size        -0.106305           0.111005  0.735454  0.067939
# horsepower          0.071622           0.203434  0.642482 -0.110711
# city-mpg           -0.035511          -0.218874 -0.642351 -0.050130
# highway-mpg         0.034671          -0.178222 -0.677632 -0.107789
# price              -0.115162           0.121582  0.716271  0.169188
#
#                    engine-size  horsepower  city-mpg  highway-mpg     price
# symboling            -0.106305    0.071622 -0.035511     0.034671 -0.115162
# normalized-losses     0.111005    0.203434 -0.218874    -0.178222  0.121582
# ...

# %%
feature["normalized-losses"]=np.log(feature["normalized-losses"])

# %%
feature["normalized-losses"]
# Out:
# 0      4.804021
# 1      4.804021
# 2      4.804021
# 3      5.099866
# 4      5.099866
#          ...
# 200    4.553877
# 201    4.553877
# 202    4.553877
# 203    4.553877
# 204    4.553877
# Name: normalized-losses, Length: 203, dtype: float64

# %%
skew(feature["normalized-losses"])
# Out:
# 0.03495278050979131

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...

# %%
s=["width","height","engine-size","horsepower",'city-mpg','highway-mpg']
# %matplotlib inline

for i in s: 
    print(i)
    plt.xlabel(i)
    plt.ylabel('price')
   plt.scatter(df[i],df.price,color='blue')
    plt.show()
# Out:
# width
# height
# engine-size
# horsepower
# city-mpg
# highway-mpg

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(xa,ds.y)
